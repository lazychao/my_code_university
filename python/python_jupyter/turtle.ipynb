# %%
import turtle
turtle.shape("turtle")
turtle.speed(1)
turtle.setup(650,350,200,200)
turtle.pencolor('blue')
turtle.forward(60)
turtle.left(120)
turtle.forward(60)

# %%
import turtle as t 
import time
t.pensize(4)
t.pencolor('red')
t.speed(0)
t.hideturtle() 
while True: 
    t.tracer(False)#如果没有  就会一闪一闪的
    t.clear()
    t.circle(100)
    t.forward(5)
    t.tracer(True)
    time.sleep(0.05)
    p = t.pos()
    if p[0]>=200:
        break
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# <ipython-input-5-c2355d49297e> in <module>()
#      12     t.tracer(True)
#      13     time.sleep(0.05)
# ---> 14     p = t.pos()
#      15     if p[0]>=200:
#      16         break
#
# ~\Anaconda3\lib\turtle.py in pos()
#
# Terminator:

# %%
#字幕动态下落
import turtle as t
import time
t.pensize(2)
t.pencolor('red')
t.speed(0) 
words = [ 'Hello','World','ABC']
x = [-100, 0, 100]
y = [ 200,200,200]
v = [-3,-5,-8]
t.penup()
t.hideturtle()
c = 0
flag = True
while flag:
    # 主循环 
    t.clear() 
    for i in range(len(words)):
        # 遍历每个单词 
        t.goto(x[i],y[i])
        #垂直下列过程中x坐标不变 
        y[i] = y[i] + v[i]
        #每循环一次更新y坐标 
        t.write(words[i],font=("Arial", 14, "normal"))
        if y[i]<= 0:
            flag = False
            break
    time.sleep(0.2)

# %%
# import
import turtle

# init screen, turtle
window = turtle.Screen()
turt = turtle.Turtle()
turt.speed(5)

def up():
    turt.forward(10)
def left():
    turt.left(10)
def right():
    turt.right(10)

while True==True:
    turtle.onkey(up, "Up")
    turtle.onkey(left, "Left")
    #turtle.onkey(right(), "Right")

# window await
turtle.listen()
window.mainloop()

# %%
class MyTurtle(Turtle):
    def glow(self,x,y)
        self.fillcolor("red")
    def unglow(self,x,y):
        self.fillcolor("")

turtle = MyTurtle()
turtle.onclick(turtle.glow)
turtle.onrelease(turtle.unglow)# clicking on turtle turns fillcolor red,turtle.onrelease(turtle.unglow)
# Out:
#   File "<ipython-input-1-4bdcf2f14508>", line 2
#     def glow(self,x,y)
#                       ^
# SyntaxError: invalid syntax

# %%
import turtle
turtle.shape("turtle")
turtle.speed(1)
turtle.begin_fill()
turtle.setup(650,350,200,200)
turtle.pencolor('blue')
turtle.fillcolor('yellow')
turtle.forward(60)
turtle.left(120)
turtle.forward(60)
turtle.left(120)
turtle.forward(60)
turtle.end_fill()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# <ipython-input-2-6cffbe2ae8e4> in <module>()
#       9 turtle.left(120)
#      10 turtle.forward(60)
# ---> 11 turtle.left(120)
#      12 turtle.forward(60)
#      13 turtle.end_fill()
#
# ~\Anaconda3\lib\turtle.py in left(angle)
#
# ~\Anaconda3\lib\turtle.py in left(self, angle)
#    1697         67.0
#    1698         """
# -> 1699         self._rotate(angle)
#    1700
#    1701     def pos(self):
#
# ~\Anaconda3\lib\turtle.py in _rotate(self, angle)
#    3274             for _ in range(steps):
#    3275                 self._orient = self._orient.rotate(delta)
# -> 3276                 self._update()
#    3277         self._orient = neworient
#    3278         self._update()
#
# ~\Anaconda3\lib\turtle.py in _update(self)
#    2658             return
#    2659         elif screen._tracing == 1:
# ...

# %% [markdown]
# #### 小猪佩奇

# %%
##pos函数返回海龟当前的xy

from turtle import *
def nose(x,y):
    pu()
    goto(x,y)
    pd()
    seth(-30)
    begin_fill()
    a=0.4
    for i in range(120):
        if 0<=i<30 or 60<=i<90:
            a=a+0.08
            lt(3)
            fd(a)
        else:
            a=a-0.08
            lt(3)
            fd(a)
    end_fill()

    pu()
    seth(90)
    fd(25)
    seth(0)
    fd(10)
    pd()
    pencolor(255,155,192)
    seth(10)
    begin_fill()
    circle(5)
    color(160,82,45)
    end_fill()

    pu()
    seth(0)
    fd(20)
    pd()
    pencolor(255,155,192)
    seth(10)
    begin_fill()
    circle(5)
    color(160,82,45)
    end_fill()

def head(x,y):
    color((255,155,192),"pink")
    pu()
    goto(x,y)
    seth(0)
    pd()
    begin_fill()
    seth(180)
    circle(300,-30)
    circle(100,-60)
    circle(80,-100)
    circle(150,-20)
    circle(60,-95)
    seth(161)
    circle(-300,15)
    pu()
    goto(-100,100)
    pd()
    seth(-30)
    a=0.4
    for i in range(60):
        if 0<=i<30 or 60<=i<90:
            a=a+0.08
            lt(3)
            fd(a)
        else:
            a=a-0.08
            lt(3)
            fd(a)
    end_fill()

def ears(x,y):
    color((255,155,192),"pink")
    pu()
    goto(x,y)
    pd()
    begin_fill()
    seth(100)
    circle(-50,50)
    circle(-10,120)
    circle(-50,54)
    end_fill()

    pu()
    seth(90)
    fd(-12)
    seth(0)
    fd(30)
    pd()
    begin_fill()
    seth(100)
    circle(-50,50)
    circle(-10,120)
    circle(-50,56)
    end_fill()

def eyes(x,y):
    color((255,155,192),"white")
    pu()
    seth(90)
    fd(-20)
    seth(0)
    fd(-95)
    pd()
    begin_fill()
    circle(15)
    end_fill()

    color("black")
    pu()
    seth(90)
    fd(12)
    seth(0)
    fd(-3)
    pd()
    begin_fill()
    circle(3)
    end_fill()

    color((255,155,192),"white")
    pu()
    seth(90)
    fd(-25)
    seth(0)
    fd(40)
    pd()
    begin_fill()
    circle(15)
    end_fill()

    color("black")
    pu()
    seth(90)
    fd(12)
    seth(0)
    fd(-3)
    pd()
    begin_fill()
    circle(3)
    end_fill()

def cheek(x,y):
    color((255,155,192))
    pu()
    goto(x,y)
    pd()
    seth(0)
    begin_fill()
    circle(30)
    end_fill()

def mouth(x,y):
    color(239,69,19)
    pu()
    goto(x,y)
    pd()
    seth(-80)
    circle(30,40)
    circle(40,80)

def body(x,y):
    color("red",(255,99,71))
    pu()
    goto(x,y)
    pd()
    begin_fill()
    seth(-130)
    circle(100,10)
    circle(300,30)
    seth(0)
    fd(230)
    seth(90)
    circle(300,30)
    circle(100,3)
    color((255,155,192),(255,100,100))
    seth(-135)
    circle(-80,63)
    circle(-150,24)
    end_fill()

def hands(x,y):
    color((255,155,192))
    pu()
    goto(x,y)
    pd()
    seth(-160)
    circle(300,15)
    pu()
    seth(90)
    fd(15)
    seth(0)
    fd(0)
    pd()
    seth(-10)
    circle(-20,90)

    pu()
    seth(90)
    fd(30)
    seth(0)
    fd(237)
    pd()
    seth(-20)
    circle(-300,15)
    pu()
    seth(90)
    fd(20)
    seth(0)
    fd(0)
    pd()
    seth(-170)
    circle(20,90)

def foot(x,y):
    pensize(10)
    color((240,128,128))
    pu()
    goto(x,y)
    pd()
    seth(-90)
    fd(40)
    seth(-180)
    color("black")
    pensize(15)
    fd(20)

    pensize(10)
    color((240,128,128))
    pu()
    seth(90)
    fd(40)
    seth(0)
    fd(90)
    pd()
    seth(-90)
    fd(40)
    seth(-180)
    color("black")
    pensize(15)
    fd(20)

def tail(x,y):
    pensize(4)
    color((255,155,192))
    pu()
    goto(x,y)
    pd()
    seth(0)
    circle(70,20)
    circle(10,330)
    circle(70,30)
    
    
def setting():
    pensize(4)
    hideturtle()
    colormode(255)
    color((255,155,192),"pink")
    setup(840,500)
    speed(10)

def main():
    setting()
    nose(-100,100)
    head(-69,167)
    ears(0,160)
    eyes(0,140)
    cheek(80,10)
    mouth(-20,30)
    body(-32,-8)
    hands(-56,-45)
    foot(2,-177)
    tail(148,-155)
    done()

main()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# <ipython-input-5-01acae6e21fd> in <module>()
#     279     done()
#     280
# --> 281 main()
#
# <ipython-input-5-01acae6e21fd> in main()
#     267 def main():
#     268     setting()
# --> 269     nose(-100,100)
#     270     head(-69,167)
#     271     ears(0,160)
#
# <ipython-input-5-01acae6e21fd> in nose(x, y)
#      16         else:
#      17             a=a-0.08
# ---> 18             lt(3)
#      19             fd(a)
#      20     end_fill()
#
# ~\Anaconda3\lib\turtle.py in lt(angle)
#
# Terminator:

# %%
##https://blog.csdn.net/lzqg1990/article/details/88092773
##circle函数的用法
from turtle import *
pensize(6)
speed(10)
hideturtle()
colormode(255)
color((0,0,0))
setup(840,500,100,100)

while True:
    begin_fill()
    fillcolor('black')
    pu()
    goto(30,100)
    seth(90)
    pd()
    circle(30,360)
    end_fill()
    #shenti
    pu()
    goto(0,70)
    seth(270)
    pd()
    fd(120)
    #zuoshou
    pu()
    goto(0,70)
    seth(215)
    pd()
    fd(60)
    left(10)
    fd(70)
    #youshou
    pu()
    goto(0,70)
    seth(325)
    pd()
    fd(60)
    right(10)
    fd(70)
    #zuojiao
    pu()
    goto(0,-50)
    seth(235)
    pd()
    fd(140)
    #youjaio
    pu()
    goto(0,-50)
    seth(305)
    pd()
    fd(140)
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# <ipython-input-1-39be3cf83011> in <module>()
#      42     #zuojiao
#      43     pu()
# ---> 44     goto(0,-50)
#      45     seth(235)
#      46     pd()
#
# ~\Anaconda3\lib\turtle.py in goto(x, y)
#
# Terminator:

# %%
help(seth)
# Out:
# Help on function seth in module turtle:
#
# seth(to_angle)
#     Set the orientation of the turtle to to_angle.
#
#     Aliases:  setheading | seth
#
#     Argument:
#     to_angle -- a number (integer or float)
#
#     Set the orientation of the turtle to to_angle.
#     Here are some common directions in degrees:
#
#      standard - mode:          logo-mode:
#     -------------------|--------------------
#        0 - east                0 - north
#       90 - north              90 - east
#      180 - west              180 - south
#      270 - south             270 - west
#
#     Example:
#     >>> setheading(90)
#     >>> heading()
#     90
